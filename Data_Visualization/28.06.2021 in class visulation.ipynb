# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats as st

# %%
diamonds=sns.load_dataset('diamonds')
exercise=sns.load_dataset('exercise')
flights=sns.load_dataset('flights')
geyser=sns.load_dataset('geyser')
iris=sns.load_dataset('iris')
penguins=sns.load_dataset('penguins')
planets=sns.load_dataset('planets')
mpg=sns.load_dataset('mpg')
tips = sns.load_dataset('tips')
titanic=sns.load_dataset('titanic')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips["size"].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
#scatter a ++++++++++numeric++++++++++ değerler girilir.------------ x ve y ekseni

# %%
plt.figure(figsize=(6,2),dpi=200)
sns.scatterplot(data=tips,x="total_bill",y="tip");

# %%
plt.figure(figsize=(8,6),dpi=200)
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="smoker");  #hue=3.boyutyaptı.

# %%
plt.figure(figsize=(10,5),dpi=200)
sns.scatterplot(x=tips["total_bill"],y=tips["tip"],hue=tips["smoker"],); # tips olarka ta yazılabilir.

# %%
plt.figure(figsize=(10,5),dpi=200)
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="sex",style="sex");

# %%
fig,ax=plt.subplots(1,2,figsize=(10,5))
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="sex",style="sex",ax=ax[0]);
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="day",ax=ax[1]);
              # burda fig ve ax verdik sonra scatter de ax ı verdik o ve  diye

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
plt.figure(figsize=(10,7),dpi=200)
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="smoker",palette="viridis");  # renk kodu viridis

# %%
sns.scatterplot(data=tips,x="total_bill",y="tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
plt.figure(figsize=(10,7),dpi=200)
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="smoker",palette="viridis",markers=markers);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-c6db3dc9a831> in <module>
#       1 plt.figure(figsize=(10,7),dpi=200)
# ----> 2 sns.scatterplot(data=tips,x="total_bill",y="tip",hue="smoker",palette="viridis",markers=markers);
#
# NameError: name 'markers' is not defined

# %%
plt.figure(figsize=(10,5))
markers={"Male": ">", "Female": "<"}
sns.scatterplot(data=tips, x='total_bill',y="tip", style='sex', hue="sex", markers=markers);

# %%
plt.figure(figsize=(10,5))
markers={"Male": ">", "Female": "<"}  # markers değişkeni tanımladık dict ile int te var
sns.scatterplot(data=tips, x='total_bill',y="tip", style='sex', hue="sex", s= 150, markers=markers);

# %% [markdown]
# https://matplotlib.org/stable/api/markers_api.html

# %%
plt.figure(figsize=(10,7),dpi=200)
markers={"Male":"*",""}
sns.scatterplot(data=tips,x="total_bill",y="tip",hue="smoker",palette="plasma");  # renk kodu viridis
                                           ##'viridis', 'plasma', 'inferno', 'magma', 'cividis'
# Out:
#   File "<ipython-input-15-9045d753976c>", line 2
#     markers={"Male":"*",""}
#                           ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(10,7),dpi=200)
sns.scatterplot(data=tips,x="total_bill",y="tip",palette="plasma",size="sex"); # size boyut kattık bayan erkek

# %%
plt.figure(figsize=(10,5),dpi=200)
sns.scatterplot(data=tips,x="total_bill",y="tip",palette="plasma",size="sex",alpha=0.7); # alpha silik hale getiriyor 0-1 arası

# %%
plt.figure(figsize=(10,5),dpi=200)
sns.scatterplot(data=tips,x="total_bill",y="tip",palette="plasma",s=300,alpha=0.5,hue="sex"); # s marker ları büyüttü.

# %%
plt.figure(figsize=(10,5),dpi=200)
sns.scatterplot(data=tips,x="total_bill",y="tip",palette="plasma",size="sex",s=200); # alpha silik hale getiriyor 0-1 arası

# %% [markdown]
# # rugplot  df ile çalışır tek boyutlu x ekseninde

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
sns.rugplot(data=mpg,x="weight"); # x ekseni dikkate alınır tek boyutlu

# %%
sns.rugplot(data=mpg,x="weight", height=0.5); # x ekseni dikkate alınır

# %% [markdown]
# # histpot     displot

# %%
# Don’n use distplot
sns.displot(x='total_bill', data=tips)  # yukarıdak,i aralıkta kaç veri var sa çizer

# %%
sns.histplot(x='total_bill', data=tips)  # displot yetenekli bir CANCAS  axes e girmez müstakil-------------- çokluda histplot çiz
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
fig, ax= plt.subplots(1,2,figsize=(10,5))         # object oriented method
sns.scatterplot(data=tips, x='total_bill',y='tip', s=300, hue='sex', ax=ax[0])
sns.histplot(data=mpg, x='weight', ax=ax[1]);
# sns.displot(data=mpg, x='weight', ax=ax[1]);     displot tek oolur canvas zaten kendisi

# %%
sns.displot(data=mpg, x="weight",kind="kde")  # displot kde, hist, ecdf  plot çizer

# %%
sns.displot(data=mpg, x="weight",kde=True, aspect=2);  # displot kde, hist, ecdf  plot çizer
                                            # kde true olursa kernel density estimation çizer.
                                            # aspect ölçeklendirir

# %%
sns.displot(data=mpg, x="weight",kind="kde")  # displot kde, hist, ecdf  plot çizer

# %% [markdown]
# ### sharey 2     y    sütunu nu aynıkullanır.

# %%
plt.figure(figsize=(6,4))    # 6 ya 4 default değeri
sns.histplot(data=mpg, x='weight', bins=20);
                                  # 10 bins default çubuk sayısı

# %%
fig,ax=plt.subplots(1,2,figsize=(12,4))    # 6 ya 4 default değeri
sns.histplot(data=mpg, x='weight', kde=True,ax=ax[0]);
sns.rugplot(data=mpg, x='weight',ax=ax[1]);                                 # 10 bins default çubuk sayısı

# %%
fig, ax = plt.subplots(1,2,figsize=(10,5))
sns.rugplot(data=mpg, x ='weight', ax= ax[0])
sns.histplot(data=mpg, x ='weight', kde = True, ax = ax[1])
# Out:
# <AxesSubplot:xlabel='weight', ylabel='Count'>

# %%
sns.set(style="dark")             # arka style
sns.histplot(data=mpg, x='weight', kde=True);

# %% [markdown]
# # KDE   tek değer alır kernel density estimation

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.kdeplot(data=penguins, x="body_mass_g")
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Density'>

# %%
sns.kdeplot(data=penguins, x="body_mass_g",hue="sex",shade=True)  # hue categoric değişkenler shade gölgeydi
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Density'>

# %%
sns.kdeplot(data=penguins, x="bill_length_mm",hue="sex",shade=True)  # hue categoric değişkenler shade gölgeydi
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Density'>

# %%
sns.kdeplot(data=tips, x="total_bill",y="tip",color="red", shade=True)  # 2 boyutlu grafik
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill",y="tip")  # 2 boyutlu grafik scatterplotta
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
fig,ax=plt.subplots(1,2, figsize=(10,4),dpi=200)
sns.scatterplot(data=tips, x="total_bill",y="tip",ax=ax[0])  # 2 boyutlu grafik scatterplotta
sns.kdeplot(data=tips, x="total_bill",y="tip",color="red", shade=True,ax=ax[1])  # 2 boyutlu grafik
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
fig,ax=plt.subplots(1,2, figsize=(10,4),dpi=200,sharey=True)  # share y burda yazılacak----------------
sns.scatterplot(data=tips, x="total_bill",y="tip",ax=ax[0])  # 2 boyutlu grafik scatterplotta
sns.kdeplot(data=tips, x="total_bill",y="tip",color="red", shade=True,ax=ax[1])  # 2 boyutlu grafik
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
penguins.head(1)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
#
#    body_mass_g   sex
# 0       3750.0  Male

# %%
sns.displot(data=penguins,x="body_mass_g",bins=10,rug=True,kde=True)  # 3 grafik aynı anda kde çizgisini çiz, 
                                                                      # rug çizgilerini çiz hist olsun

# %% [markdown]
# # https://seaborn.pydata.org/examples/index.html

# %% [markdown]
# # jointplot    t yi unutma joint

# %%
sns.jointplot(data=tips,x="total_bill",y="tip", kind="scatter")   # scatter plot ve histogram birleşti.
                                                                #  { "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" }

# %%
sns.jointplot(data=tips,x="total_bill",y="tip", kind="hist")   # scatter plot ve histogram birleşti.
                                                                #  { "scatter" | "kde" | "hist" | "hex" | "reg" | "resid" }

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
sns.jointplot(data=mpg,x="horsepower",y="acceleration",kind="hex")

# %%
sns.jointplot(data=mpg,x="horsepower",y="acceleration",kind="hex")
