# %% [markdown]
# # data input and output

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("example.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-f69ba4450692> in <module>
# ----> 1 df=pd.read_csv("example.csv")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df1=pd.read_csv("sample.csv")

# %% [markdown]
# df1

# %%
df1
# Out:
#     x   w   y   z
# 0   1   2   3   4
# 1   5   6   7   8
# 2   9  10  11  12
# 3  13  14  15  16

# %%
df1.to_csv("sample_2.csv")

# %%
pd.read_csv("sample_2.csv")  #ilave index koydu
# Out:
#    Unnamed: 0   x   w   y   z
# 0           0   1   2   3   4
# 1           1   5   6   7   8
# 2           2   9  10  11  12
# 3           3  13  14  15  16

# %%
pd.read_csv("sample_2.csv",index_col=0)  #0. column index olarak aldı.
# Out:
#     x   w   y   z
# 0   1   2   3   4
# 1   5   6   7   8
# 2   9  10  11  12
# 3  13  14  15  16

# %%
df2=pd.read_csv("titanic.csv")

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df3=pd.read_csv("titanictt.csv",sep="\t") # tsv  t ile ayır getir dedik

# %%
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic=pd.read_csv("titanictt.csv",sep="\t")

# %%
titanic.to_json("json.titanic.json")  # json formatına dönüştü.

# %%
pd.read_csv("ornekcsv.csv")
# Out:
#        a;b;c
# 0    78;12;1
# 1    78;12;2
# 2   78;324;3
# 3      7;2;4
# 4    88;23;5
# 5       6;2;
# 6    56;11;6
# 7     7;12;7
# 8    56;21;7
# 9    346;2;8
# 10     5;1;8
# 11  456;21;8
# 12   3;12;88

# %%
with open("ornekcsv.csv","r", encoding="utf-8") as f:
    print(f.read())
# Out:
# a;b;c
# 78;12;1
# 78;12;2
# 78;324;3
# 7;2;4
# 88;23;5
# 6;2;
# 56;11;6
# 7;12;7
# 56;21;7
# 346;2;8
# 5;1;8
# 456;21;8
# 3;12;88

# %%
pd.read_csv("ornekcsv.csv",sep=";") # sep i biz verdik
# Out:
#       a    b     c
# 0    78   12   1.0
# 1    78   12   2.0
# 2    78  324   3.0
# 3     7    2   4.0
# 4    88   23   5.0
# 5     6    2   NaN
# 6    56   11   6.0
# 7     7   12   7.0
# 8    56   21   7.0
# 9   346    2   8.0
# 10    5    1   8.0
# 11  456   21   8.0
# 12    3   12  88.0

# %%
# ornekcsv kaydedeceğim ama index fazladan gelmesin

# %%
ornek=pd.read_csv("ornekcsv.csv",sep=";")

# %%
ornek=pd.read_csv("ornekcsv.csv",sep=";")

# %%
ornek.to_csv("ornekcsv.csv",index=False)# ornekcsv kaydedeceğim ama index fazladan gelmesin kaydederken çözdük
#okurken index false dersek nasıl yapacak

# %%
df=pd.read_excel("Excel_Sample.xlsx")

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df1=pd.read_excel("Excel_Sample.xlsx",sheet_name="Sheet2")  # sheeti 2. exceel sekmesini açtık 
                                                            # veya 1. dersek shee_name 1. sekme açtı

# %%
df1
# Out:
#     a   b    c   d
# 0  11  55  123   3
# 1  22  66  234   7
# 2  33  77  456  11
# 3  44  88  678  15

# %%
pd.read_excel("ornekx.xlsx")  # boşlar nan oldu, float değrler verdi int aslı nan girince floa oldu
# Out:
#         a      b     c
# 0    78.0   12.0   1.0
# 1    78.0   12.0   2.0
# 2    78.0  324.0   3.0
# 3     7.0    2.0   4.0
# 4     NaN   23.0   5.0
# 5     6.0    2.0   NaN
# 6     NaN   11.0   6.0
# 7     7.0   12.0   7.0
# 8    56.0   21.0   7.0
# 9   346.0    NaN   8.0
# 10    5.0    1.0   8.0
# 11  456.0   21.0   8.0
# 12    3.0   12.0  88.0

# %%
df.to_excel("Excel_Sample_1.xlsx",sheet_name="Sheet-1",index=False) # sheet 1 olark kaydet ,ilave index verme

# %%
df=pd.read_html("https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/")
df[0]   #web browser dan linki aldık çalıştı.      df[0] df oldu
# Out:
#                          Bank NameBank           CityCity StateSt  CertCert  \
# 0                    Almena State Bank             Almena      KS     15426
# 1           First City Bank of Florida  Fort Walton Beach      FL     16748
# 2                 The First State Bank      Barboursville      WV     14361
# 3                   Ericson State Bank            Ericson      NE     18265
# 4     City National Bank of New Jersey             Newark      NJ     21111
# ..                                 ...                ...     ...       ...
# 558                 Superior Bank, FSB           Hinsdale      IL     32646
# 559                Malta National Bank              Malta      OH      6629
# 560    First Alliance Bank & Trust Co.         Manchester      NH     34264
# 561  National State Bank of Metropolis         Metropolis      IL      3815
# 562                   Bank of Honolulu           Honolulu      HI     21029
#
# ...
