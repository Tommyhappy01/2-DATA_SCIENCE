# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
tips=sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x="day",data=tips)# sns de coutplot saydı hangigün ne kadr alışveriş
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
fig,ax_tip=plt.subplots(figsize=(12,6))
ax_tip=sns.countplot(x="day",data=tips)
#sns.countplot(x="day",data=tips,ax_tip=)# sns de coutplot saydı hangigün ne kadr alışveriş

for p in ax_tip.patches:
    ax_tip.annotate((p.get_height()), (p.get_x()+0.3, p.get_height()+1));

# %%
sns.countplot(tips.day)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.countplot(tips["day"])
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
fig,ax_tip=plt.subplots(figsize=(12,6))
ax_tip=sns.countplot(x="day",data=tips,hue="smoker")
#sns.countplot(x="day",data=tips,ax_tip=)# sns de coutplot saydı hangigün ne kadr alışveriş

for p in ax_tip.patches:
    ax_tip.annotate((p.get_height()), (p.get_x()+0.1, p.get_height()+1));

# %%
fig,ax_tip=plt.subplots(figsize=(12,6))
ax_tip=sns.countplot(x="day",data=tips,hue="size")
#sns.countplot(x="day",data=tips,ax_tip=)# sns de coutplot saydı hangigün ne kadr alışveriş

for p in ax_tip.patches:
    ax_tip.annotate((p.get_height()), (p.get_x()+0.005, p.get_height()+1));

# %%
fig,ax_tip=plt.subplots(figsize=(12,6))
ax_tip=sns.countplot(x="day",data=tips)
#sns.countplot(x="day",data=tips,ax_tip=)# sns de coutplot saydı hangigün ne kadr alışveriş

for p in ax_tip.patches:
    ax_tip.annotate((p.get_height()), (p.get_x()+0.3, p.get_height()+1))
    ax_tip.annotate("%"+str(round((p.get_height()/tips.day.count()*100),2)), (p.get_x()+0.3, p.get_height()-5));

# %%
sns.barplot("sex","tip",data=tips)  # ortalama verir
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.barplot("sex","tip",data=tips,estimator=np.median) # np dan çağırdık
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.barplot("sex","tip",data=tips,estimator=np.sum) # np dan çağırdık
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.barplot("sex","tip",data=tips,estimator=np.max) # np dan çağırdık
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.barplot("sex","tip",data=tips,estimator=np.mean,ci="sd",hue="smoker")  # ci %95 sd yzdık,  hue smoker yaptık
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.barplot("day","tip",data=tips,estimator=np.mean,ci="sd",hue="smoker")  # ci %95 sd yzdık,  hue smoker yaptık günlük bahşişler
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.barplot("tip",data=tips,estimator=np.mean,ci="sd")  # ci %95 sd yzdık, -------std 1,3---------
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
sns.barplot("total_bill",data=tips,estimator=np.mean,ci="sd")  # ci %95 sd yzdık, -------std 1,3---------
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(16,6))

sns.barplot(data=tips,x="day",y="total_bill",ax=ax[0],estimator=np.count_nonzero)

sns.countplot(data= tips,x="day",ax=ax[1])
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(16,6))

sns.barplot(data=tips,x="day",y="total_bill",ax=ax[0],estimator=np.median)

sns.countplot(data= tips,x="day",ax=ax[1])
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(16,6))

sns.barplot(data=tips,x="day",y="total_bill",ax=ax[0],estimator=np.mean)

sns.countplot(data= tips,x="day",ax=ax[1])
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %% [markdown]
# # boxplot

# %%
sns.boxplot(x="day",y="tip",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.boxplot(tips.day,tips.tip,data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.boxplot(tips.day,tips.total_bill,data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(tips.day,tips.total_bill,data=tips,hue="sex")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(tips.day,tips.tip,data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(tips.tip,tips.day,data=tips,hue="sex",width=0.7)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot(tips.tip,tips.day,data=tips,hue="sex",width=0.7)
plt.legend(loc=2)

# %% [markdown]
# # violinplot

# %%
plt.figure(figsize=(12,6))
sns.violinplot(tips.day,tips.tip,data=tips,hue="sex",width=0.7)   #vvvvvv aynı
plt.legend(loc=2)

# %%
plt.figure(figsize=(12,6))
sns.boxplot(tips.day,tips.tip,data=tips,hue="sex",width=0.7)   #^^^^^^ aynı
plt.legend(loc=2)

# %%
plt.figure(figsize=(12,6))
sns.violinplot(tips.day,tips.tip,data=tips,hue="sex",width=0.7,split=True)   #split true hue yanyana oldu---------------
plt.legend(loc=2)

# %%
plt.figure(figsize=(12,6))
sns.violinplot(tips.tip,tips.day,data=tips,hue="sex",width=0.7,split=True)   #split true hue yanyana oldu---------------
plt.legend(loc=2)                                                            #yana yatırdık---------------

# %%
plt.figure(figsize=(12,6))
sns.violinplot(tips.tip,tips.day,data=tips,hue="sex",width=0.5,split=True,bw=0.2)   #split true hue yanyana oldu---------------
plt.legend(loc=2)                                       #bw   daha gerçekçi ekledik küçüldükçe yığın gördük--------------

# %%
plt.figure(figsize=(12,6))
sns.violinplot(tips.tip,tips.day,data=tips,hue="sex",width=0.5,split=True,bw=0.2)   #split true hue yanyana oldu---------------
plt.legend(loc=2)                                                                  #bw   daha gerçekçi ekledik küçüldükçe yığın gördük--------------
#bw{‘scott’, ‘silverman’, float}, optional
#Either the name of a reference rule or the scale factor to use when computing the kernel bandwidth.
#The actual kernel size will be determined by multiplying the scale factor by the standard deviation of the data within each bin.
#Böyle bir açıklaması var ama anlamadın İngiliççe

# %% [markdown]
# # swarmplot

# %%
plt.figure(figsize=(12,6))
sns.swarmplot(x="total_bill",data=tips,size=10,y="smoker",hue="sex")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='smoker'>

# %%
plt.figure(figsize=(12,6))
sns.swarmplot(x="total_bill",data=tips,size=10,y="smoker",hue="sex",dodge=True)# dodge ile noktalrı ayırdık
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='smoker'>

# %% [markdown]
# # boxen plot

# %%
plt.figure(figsize=(12,6))
sns.boxenplot(tips.tip,tips.day,data=tips,hue="sex",width=0.7)
plt.legend(loc=2)

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
flights=sns.load_dataset("flights")
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
### https://seaborn.pydata.org/generated/seaborn.lineplot.html

# %%
plt.figure(figsize=(12,6))
sns.lineplot("year","passengers",data=flights)
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
plt.figure(figsize=(12,6))
sns.lineplot("year","passengers",data=flights)
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
y=flights.groupby(["year","month"]).sum().values  # 49 ocak 6 aralık ayına kadar
y
# Out:
# array([[112],
#        [118],
#        [132],
#        [129],
#        [121],
#        [135],
#        [148],
#        [148],
#        [136],
#        [119],
#        [104],
#        [118],
#        [115],
#        [126],
#        [141],
#        [135],
#        [125],
#        [149],
#        [170],
#        [170],
#        [158],
#        [133],
#        [114],
#        [140],
#        [145],
#        [150],
#        [178],
#        [163],
#        [172],
#        [178],
#        [199],
#        [199],
#        [184],
#        [162],
#        [146],
#        [166],
#        [171],
#        [180],
#        [193],
#        [181],
#        [183],
#        [218],
#        [230],
#        [242],
#        [209],
#        [191],
#        [172],
#        [194],
#        [196],
#        [196],
#        [236],
#        [235],
#        [229],
#        [243],
#        [264],
#        [272],
#        [237],
#        [211],
#        [180],
#        [201],
#        [204],
#        [188],
# ...

# %%
y=flights.groupby(["year","month"]).sum().values  # 49 ocak 6 aralık ayına kadar
y.multi_index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-137-f5bf63bbf1df> in <module>
#       1 x=flights.groupby(["year","month"]).sum().values  # 49 ocak 6 aralık ayına kadar
# ----> 2 x.multi_index
#
# AttributeError: 'numpy.ndarray' object has no attribute 'multi_index'

# %%
flights.passengers.values
# Out:
# array([112, 118, 132, 129, 121, 135, 148, 148, 136, 119, 104, 118, 115,
#        126, 141, 135, 125, 149, 170, 170, 158, 133, 114, 140, 145, 150,
#        178, 163, 172, 178, 199, 199, 184, 162, 146, 166, 171, 180, 193,
#        181, 183, 218, 230, 242, 209, 191, 172, 194, 196, 196, 236, 235,
#        229, 243, 264, 272, 237, 211, 180, 201, 204, 188, 235, 227, 234,
#        264, 302, 293, 259, 229, 203, 229, 242, 233, 267, 269, 270, 315,
#        364, 347, 312, 274, 237, 278, 284, 277, 317, 313, 318, 374, 413,
#        405, 355, 306, 271, 306, 315, 301, 356, 348, 355, 422, 465, 467,
#        404, 347, 305, 336, 340, 318, 362, 348, 363, 435, 491, 505, 404,
#        359, 310, 337, 360, 342, 406, 396, 420, 472, 548, 559, 463, 407,
#        362, 405, 417, 391, 419, 461, 472, 535, 622, 606, 508, 461, 390,
#        432], dtype=int64)

# %%
plt.figure(figsize=(12,6))
sns.lineplot(y=flights.passengers.values, x= flights.index)
# Out:
# <AxesSubplot:>

# %%
flights_wide = flights.pivot("year", "month", "passengers")
flights_wide.head()
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=flights_wide.T)
# Out:
# <AxesSubplot:xlabel='month'>

# %%
sns.lineplot(data=flights_wide)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
sns.lineplot(data = flights, x = 'month', y = 'passengers', hue='year') # yıllara göre aylar geldi
plt.legend(loc=(1.1,.0))

# %%
sns.lineplot(data = flights, x = 'month', y = 'passengers',palette="inferno") # hue kalkınca yıllara göre aylar geldi
plt.legend(loc=(1.1,.0))
# Out:
# No handles with labels found to put in legend.

# %%
sns.lineplot(data = flights, x = 'month', y = 'passengers',palette="inferno",hue="year") # hue kalkınca yıllara göre aylar geldi
plt.legend(loc=(1.1,.0))

# %%
sns.pointplot(data = flights, x = 'month', y = 'passengers',palette="inferno",hue="year") # hue kalkınca yıllara göre aylar geldi
plt.legend(loc=(1.1,.0))
