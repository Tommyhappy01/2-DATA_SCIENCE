# %%
import pandas as pd
import numpy as np

# %%
reviews=pd.read_csv("winemag-data-130k-v2.csv",index_col="province")
reviews
# Out:
#                    Unnamed: 0   country  \
# province
# Sicily & Sardinia           0     Italy
# Douro                       1  Portugal
# Oregon                      2        US
# Michigan                    3        US
# Oregon                      4        US
# ...                       ...       ...
# Mosel                  129966   Germany
# Oregon                 129967        US
# Alsace                 129968    France
# Alsace                 129969    France
# Alsace                 129970    France
#
#                                                          description  \
# province
# Sicily & Sardinia  Aromas include tropical fruit, broom, brimston...
# Douro              This is ripe and fruity, a wine that is smooth...
# Oregon             Tart and snappy, the flavors of lime flesh and...
# Michigan           Pineapple rind, lemon pith and orange blossom ...
# Oregon             Much like the regular bottling from 2012, this...
# ...

# %%
reviews.set_index("country")
# Out:
#           Unnamed: 0                                        description  \
# country
# Italy              0  Aromas include tropical fruit, broom, brimston...
# Portugal           1  This is ripe and fruity, a wine that is smooth...
# US                 2  Tart and snappy, the flavors of lime flesh and...
# US                 3  Pineapple rind, lemon pith and orange blossom ...
# US                 4  Much like the regular bottling from 2012, this...
# ...              ...                                                ...
# Germany       129966  Notes of honeysuckle and cantaloupe sweeten th...
# US            129967  Citation is given as much as a decade of bottl...
# France        129968  Well-drained gravel soil gives this wine its c...
# France        129969  A dry style of Pinot Gris, this is crisp with ...
# France        129970  Big, rich and off-dry, this is powered by inte...
#
#                                      designation  points  price  \
# country
# ...

# %%
reviews.head()
# Out:
#                    Unnamed: 0   country  \
# province
# Sicily & Sardinia           0     Italy
# Douro                       1  Portugal
# Oregon                      2        US
# Michigan                    3        US
# Oregon                      4        US
#
#                                                          description  \
# province
# Sicily & Sardinia  Aromas include tropical fruit, broom, brimston...
# Douro              This is ripe and fruity, a wine that is smooth...
# Oregon             Tart and snappy, the flavors of lime flesh and...
# Michigan           Pineapple rind, lemon pith and orange blossom ...
# Oregon             Much like the regular bottling from 2012, this...
#
#                                           designation  points  price  \
# province
# Sicily & Sardinia                        Vulkà Bianco      87    NaN
# Douro                                        Avidagos      87   15.0
# ...

# %%
animals = pd.DataFrame({'Cows': [12, 20], 'Goats': [22, 19]}, index=['Year 1', 'Year 2'])
animals
# Out:
#         Cows  Goats
# Year 1    12     22
# Year 2    20     19

# %%
animals.to_csv("hayvanlar.csv")
