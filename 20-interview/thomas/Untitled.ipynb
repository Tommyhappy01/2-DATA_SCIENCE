# %%
import pandas as pd

# %%
df=pd.read.xlsx('Task1.xlsx')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-7fefe8cad676> in <module>
# ----> 1 df=pd.read.xlsx('Task1.xlsx')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
df.TELEFON
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-2738b4d86e05> in <module>
# ----> 1 df.TELEFON
#
# NameError: name 'df' is not defined

# %%
df.columns=['musteri_no','tel']

# %%
df.TELEFON.str.replace(' ','')

# %%
df
