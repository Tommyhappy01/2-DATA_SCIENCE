# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %% [markdown]
# read data
#
# if didn't work you can use this parameters: encoding="windows-1252"

# %%
df = pd.read_csv('PoliceKillingsUS.csv', encoding="windows-1252")

# %%
df.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
df.shape
# Out:
# (2535, 14)

# %%
df.isnull().sum()
# Out:
# id                           0
# name                         0
# date                         0
# manner_of_death              0
# armed                        9
# age                         77
# gender                       0
# race                       195
# city                         0
# state                        0
# signs_of_mental_illness      0
# threat_level                 0
# flee                        65
# body_camera                  0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (2254, 14)

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %%
df.columns
# Out:
# Index(['id', 'name', 'date', 'manner_of_death', 'armed', 'age', 'gender',
#        'race', 'city', 'state', 'signs_of_mental_illness', 'threat_level',
#        'flee', 'body_camera'],
#       dtype='object')

# %%
df.manner_of_death.unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %%
df.manner_of_death.value_counts()
# Out:
# shot                2100
# shot and Tasered     154
# Name: manner_of_death, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data = df, x = 'gender', y = 'age', hue = 'manner_of_death')
plt.legend(loc = (0));

# %%
df.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
df.manner_of_death.unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
sns.boxplot(data = df, x = 'gender', y = 'age', hue = 'manner_of_death')
plt.legend(loc = (0))

# %%
# with seaborn

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
df.groupby('gender').age.describe()
# Out:
#          count       mean        std   min    25%   50%    75%   max
# gender
# F         94.0  36.202128  12.154542  12.0  26.25  36.0  44.75  71.0
# M       2160.0  36.256481  12.870285   6.0  26.00  34.0  45.00  91.0

# %%
sns.swarmplot(data = df, x = 'gender', y = 'age', hue = 'manner_of_death')
plt.legend(loc = (0))
plt.xlabel("Gender")
plt.ylabel("Age");

# %%
plt.figure(figsize=(12,6), dpi = 150)
sns.swarmplot(data = df, x = 'gender', y = 'age', hue = 'manner_of_death')
plt.xlabel("Gender")
plt.ylabel("Age");

# %%
# with seaborn

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
df.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
df.isnull().sum()
# Out:
# id                         0
# name                       0
# date                       0
# manner_of_death            0
# armed                      0
# age                        0
# gender                     0
# race                       0
# city                       0
# state                      0
# signs_of_mental_illness    0
# threat_level               0
# flee                       0
# body_camera                0
# dtype: int64

# %%
most_danger_city = df.city.value_counts().head(12)  # bu şekilde de olur [:12]

# %%
most_danger_city
# Out:
# Los Angeles     35
# Phoenix         28
# Houston         24
# Chicago         22
# Austin          18
# Las Vegas       17
# Columbus        16
# San Antonio     15
# Miami           15
# St. Louis       14
# Indianapolis    14
# Bakersfield     13
# Name: city, dtype: int64

# %%
sns.barplot(data=most_danger_city,x=most_danger_city.index, y=most_danger_city.values)
# Out:
# <AxesSubplot:xlabel='city'>

# %%
most_danger_city.plot.bar()
# Out:
# <AxesSubplot:>

# %%
fig, ax =plt.subplots(figsize=(8,5))
ax = sns.barplot(x=most_danger_city.index, y=most_danger_city.values)
ax.set_xticklabels(most_danger_city.index, rotation = 45)
ax.set_title('Most Dangerous Cities',color = 'blue',fontsize=15)
plt.tight_layout();

# %%
x = most_danger_city.index
x
# Out:
# Index(['Los Angeles', 'Phoenix', 'Houston', 'Chicago', 'Austin', 'Las Vegas',
#        'Columbus', 'San Antonio', 'Miami', 'St. Louis', 'Indianapolis',
#        'Bakersfield'],
#       dtype='object')

# %%
y = most_danger_city.values
y
# Out:
# array([35, 28, 24, 22, 18, 17, 16, 15, 15, 14, 14, 13], dtype=int64)

# %%
plt.figure(figsize=(12,6),dpi = 150)
sns.barplot(x,y, palette='viridis')
plt.xticks(rotation = 60);
for index , value in enumerate(y):
    plt.text(index, value+0.1, str(value), ha = 'center')
plt.title('Most Dangerous City',color = 'orange');

# %%
most_danger_city.index
# Out:
# Index(['Los Angeles', 'Phoenix', 'Houston', 'Chicago', 'Austin', 'Las Vegas',
#        'Columbus', 'San Antonio', 'Miami', 'St. Louis', 'Indianapolis',
#        'Bakersfield'],
#       dtype='object')

# %%
sns.barplot(x = df.city.value_counts()[:12].index, y = df.city.value_counts()[:12].values)
# Out:
# <AxesSubplot:>

# %%
most_danger_city.index
# Out:
# Index(['Los Angeles', 'Phoenix', 'Houston', 'Chicago', 'Austin', 'Las Vegas',
#        'Columbus', 'San Antonio', 'Miami', 'St. Louis', 'Indianapolis',
#        'Bakersfield'],
#       dtype='object')

# %%
plt.figure(figsize=(16,6))
sns.countplot(data = df , x = 'city', order = most_danger_city.index);
plt.xticks(rotation = 60)
plt.show()
# y ekseni deafult geliyor

# %%
# with seaborn countplot

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
mds = df.state.value_counts()[:20] # mds = shorteness of most dangerous state

# %%
mds
# Out:
# CA    366
# TX    200
# FL    136
# AZ    105
# OH     70
# NC     66
# OK     65
# CO     63
# GA     61
# MO     58
# TN     56
# IL     56
# WA     51
# LA     47
# PA     45
# AL     45
# NY     43
# VA     43
# WI     42
# NM     41
# Name: state, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.barplot(mds.index, mds.values);
plt.xticks(rotation = 60);
plt.title('Most Dangerous States');

# %%
# with seaborn barplot

# %%
plt.figure(figsize=(12,6))
sns.countplot(data = df , x = 'state', order=mds.index)
plt.title('Most Dangerous States');

# %%
# with seaborn countplot

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
signs_of_mental_illness = df.signs_of_mental_illness.value_counts()
signs_of_mental_illness
# Out:
# False    1681
# True      573
# Name: signs_of_mental_illness, dtype: int64

# %%
sns.countplot(x=df.signs_of_mental_illness)
# Out:
# <AxesSubplot:xlabel='signs_of_mental_illness', ylabel='count'>

# %%
sns.barplot(x = signs_of_mental_illness.index, y = signs_of_mental_illness.values)
for index, value in enumerate(signs_of_mental_illness):
    plt.text(index,value+10,str(value), ha = 'center')

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
threat_level = df.threat_level.value_counts()
threat_level
# Out:
# attack          1462
# other            677
# undetermined     115
# Name: threat_level, dtype: int64

# %%
sns.barplot(x = threat_level.index, y = threat_level.values)
for index, value in enumerate(threat_level):
    plt.text(index,value+10,str(value), ha = 'center')

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
flee = df.flee.value_counts()
flee
# Out:
# Not fleeing    1528
# Car             360
# Foot            278
# Other            88
# Name: flee, dtype: int64

# %%
sns.barplot(x=flee.index, y = flee.values)
for index, value in enumerate(flee):
    plt.text(index,value+10,str(value), ha = 'center')

# %%
sns.countplot(df.flee)
for index, value in enumerate(flee):
    plt.text(index,value+10,str(value), ha = 'center')

# %%
"""
Mary-Mentor  8:33 PM
https://plotly.com/python/bar-charts/"""
