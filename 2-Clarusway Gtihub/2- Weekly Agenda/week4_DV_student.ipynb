# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Set darkgrid style from seaborn

# %%
sns.set_style(style="darkgrid")

# %% [markdown]
# Bar plots

# %%
income = [100, 80, 150, 48, 52, 69, 88]
expense = [30, 100, 100, 20, 75, 50, 28]
index = ['A', 'B', 'C','D', 'E', 'F', 'G']
df = pd.DataFrame({'income': income,'expense': expense}, index=index)
df.head()
# Out:
#    income  expense
# A     100       30
# B      80      100
# C     150      100
# D      48       20
# E      52       75

# %%
#df.reset_index()

# %% [markdown]
# # 2. Make a bar plot

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=index)

# %%
index_axis = np.arange(len(index))
  
plt.bar(index_axis - 0.2, income, 0.4, label = 'income')
plt.bar(index_axis + 0.2, expense, 0.4, label = 'expense')
  
plt.xticks(index_axis, index)

plt.legend();

# %% [markdown]
# fig, ax = plt.subplots()
# x=len(df.index)
# ax.bar(x-0.2,index, expense, label="income",align="edge")
# ax.bar(x,index, income, label="expense",width=0.4, align="edge")
# plt.legend()
# plt.show()

# %% [markdown]
# # 3. Stack the bars

# %%
df.plot.bar(stacked=True)  # stack üstüste getirdi.
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 3. Rotate the labels and set figsize

# %%
fig,axis=plt.subplots(figsize=(9,6))
df.plot.bar(ax=axis,stacked=True) # df pandas yukarda canvas  aşağıda canvas var eşitlemek için ax=axis
plt.xticks(rotation=0);

# %% [markdown]
# # 4. Replace the labels by "Game-1", "Game-2", "Game-3", "Game-4", "Game-5", "Game-6", "Game-7"
# # 5. Unstuck the bars, annotate the hight of the bars on top of them

# %%
labels=["Game-1", "Game-2", "Game-3", "Game-4", "Game-5", "Game-6", "Game-7"]

# %%
fig , axis = plt.subplots(figsize = (9,6))
df.plot.bar(ax = axis)
plt.xticks(rotation = 0);
for index, value in enumerate(income):
    plt.text(index, value, str(value), ha = 'right')
for index, value in enumerate(expense):
    plt.text(index, value, str(value), ha = 'left')

# %%
## histograms

# %%
tips=sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # 6. Histogram of the total_bill column

# %%
plt.hist(data=tips, x="total_bill");

# %%
tips.total_bill.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
## lineplots

# %%
(tips.tip/tips.size).plot.line().agg(np.avg)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-5f652bc92ced> in <module>
# ----> 1 (tips.tip/tips.size).plot.line().agg(np.avg)
#
# AttributeError: 'AxesSubplot' object has no attribute 'agg'

# %%
tips[[]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-134-87040fde2c56> in <module>
# ----> 1 plt.lineplot(total_bill)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'lineplot'

# %%
tips.groupby("size").tip.mean()
# Out:
# size
# 1    1.437500
# 2    2.582308
# 3    3.393158
# 4    4.135405
# 5    4.028000
# 6    5.225000
# Name: tip, dtype: float64

# %%
tips.groupby("size").tip.mean().plot.line()  # default line olduğu için size groupby yapıldı
# Out:
# <AxesSubplot:xlabel='size'>

# %% [markdown]
# # 7. Plot the avg tip by size  (lineplot)

# %% [markdown]
# # 8.Set the linestyle as "--"

# %%
tips.groupby("size").tip.mean().plot(kind="line",style="--")
# Out:
# <AxesSubplot:xlabel='size'>

# %%
## Scatter Plots

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # 9. Make a scatter plot between tip and total_bill

# %%
sns.scatterplot(data=tips,x="tip",y="total_bill")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
x=tips.tip
y=tips.total_bill
plt.scatter(x,y,alpha=0.9,s=10)

# %%
tips.plot.scatter("tip","total_bill")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# # 10. Set an additional dimension using size column

# %%
sns.scatterplot(data=tips,x="tip",y="total_bill",size="size",ci="size",palette="inferno")  # sns le yaptık
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
tips.plot.scatter("tip",y="total_bill",c="size",cmap="inferno")  # c sağa lejenad yaptı çift eksen

# %%
## boxplots

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # 11. Make the same plot using seaborn

# %%
sns.boxplot(data=tips,x="size",y="total_bill")
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %% [markdown]
# # 12. Make a violinplot instead of boxplot and discuss the difference between boxplot and violinplot

# %%
sns.violinplot(data=tips,x="size",y="total_bill")
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
fig, ax = plt.subplots(2,2, figsize = (16,9))

sns.violinplot(data = tips, x = "size", y = "total_bill", ax = ax[0,0]);
sns.boxplot(data = tips, x = 'size', y = 'total_bill',ax = ax[0,1])
tips.plot.scatter('tip', y = 'total_bill', c = 'size', cmap = 'inferno', ax = ax[1,0])
tips.total_bill.plot.hist(ax = ax[1,1]);
#plt.text('Bu grafik kullanılmayacak', ax = ax[1,1])

# %%
g.fig.text(0.85, 0.85,'Text Here', fontsize=9)
