# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats as st

# %%
pd.__version__
# Out:
# '1.2.4'

# %%
sns.__version__
# Out:
# '0.11.1'

# %%
import matplotlib
print('matplotlib: {}'.format(matplotlib.__version__))
# Out:
# matplotlib: 3.3.4

# %%
plt.matplotlib.__version__
# Out:
# '3.3.4'

# %%
age = [25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45]
salary = [38496, 42000, 46752, 49320, 53200, 56000, 62316, 64928, 67317, 68748, 73752]

# %%
df = pd.DataFrame({"age" : [25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45], "salary" : [38496, 42000, 46752, 49320, 53200, 56000, 62316, 64928, 67317, 68748, 73752]
    }, index=[25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45])
df.head()
# Out:
#     age  salary
# 25   25   38496
# 27   27   42000
# 29   29   46752
# 31   31   49320
# 33   33   53200

# %%
lines=df.plot.line(x="age",y="salary")
# Out:
# <AxesSubplot:xlabel='age'>

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.line()
# Out:
# <AxesSubplot:>

# %%
plt.plot(age,salary)

# %%
plt.plot(salary)

# %%
plt.plot(age,salary)
plt.xlabel("age")
plt.ylabel("salary")
plt.title("salary by age")
plt.show()

# %%
fig,ax=plt.subplots(figsize=(15,5))
                  
ax.plot(age,salary,"r")
ax.set_xlabel("age")
ax.set_ylabel("salary")
ax.set_title("salary and age");

# %%
plt.subplot(2,3,1)
plt.plot()
plt.subplot(2,3,2)
plt.plot()
plt.subplot(2,3,3)
plt.plot()
plt.subplot(2,3,4)
plt.plot()
plt.subplot(2,3,5)
plt.plot()
plt.subplot(2,3,6)
plt.plot()
plt.tight_layout()

# %%
salary_2 = [45372, 48876, 53850, 57287, 63016,65998, 70003, 70000, 71496, 75370, 83640]

# %%
# functional
plt.subplot(1,2,1)
plt.plot(age, salary, "r")
plt.xlabel("age vs salary1")

plt.subplot(1,2,2)
plt.plot(age, salary_2, "b")
plt.xlabel("age vs salary2")

plt.tight_layout()
plt.show()

# %%
# functional
plt.subplot(1,2,1)
plt.plot(age, salary, "r")
plt.xlabel("age vs salary1")

plt.subplot(1,2,1)
plt.plot(age, salary_2, "b")
plt.xlabel("age vs salary2")

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-54-ed16b72581db>:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(1,2,1)

# %%
plt.plot(age, salary, "r")
plt.xlabel("age vs salary1")

plt.plot(age, salary_2, "b")
plt.title("age vs salary2")

plt.tight_layout()
plt.show()

# %%
x = np.arange(1,11)
y = x.copy()
z = x*2
t = np.log(x)

# %%
fig, ax = plt.subplots(2,3)

ax[1,1].plot(x,y)
ax[0,2].plot(x,x**2)

plt.tight_layout()
plt.show()

# %%
plt.subplot(2,2,1)
plt.plot(age, salary, "r+")
plt.subplot(2,2,2)
plt.plot(age, salary, "b--")
plt.subplot(2,2,3)
plt.plot(age, salary, "mo")
plt.subplot(2,2,4)
plt.plot(age, salary, "c.")
plt.tight_layout()

# %%
fig,ax=plt.subplots(figsize=(15,5))

ax.plot(x,y,"r",ls="--")
ax.plot(x,y-1,"b",ls="--")
ax.plot(x,y-2,"b",ls="--")
ax.plot(x,y-3,"brown",ls="--")

plt.show()

# %%
plt.plot(age, salary, label="salary")
plt.plot(age, salary_2, label="salary_2")

plt.xlabel("age")
plt.ylabel("salary")
plt.title("Salary by Age")

plt.axvline(x=np.mean(age), ymin=0, ymax=8, ls="--")
plt.legend(loc=0);
plt.show()

# %%
x = np.arange(1,10)
fig, ax = plt.subplots(nrows=1,ncols=2, figsize=(10,4))
ax[0].plot(x,x**2, x,x**3, x,x**4)
ax[1].plot(x,x**2, x,x**3, x,x**4)
ax[1].set_xlim([2,4])
ax[1].set_ylim([5,100])
ax[0].axvline(x=3,ls="--")
ax[0].axhline(y=50,ls="--")
ax[1].axvline(x=3,ls="--")
ax[1].axhline(y=50,ls="--")

# %%
fig,ax=plt.subplots(nrows=1,ncols=3,figsize=(10,5))
ax[0].plot(x,x**2,x,x**3)
ax[0].set_title("ilk")
ax[1].plot(x,x**2,x,x**3)
ax[1].set_xlim(2,4)
ax[1].set_ylim(0,60)
# Out:
# (0.0, 60.0)

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.scatter(tips["tip"], tips["total_bill"])

# %%
day = tips.groupby("day")["total_bill"].sum()
day
# Out:
# day
# Thur    1096.33
# Fri      325.88
# Sat     1778.40
# Sun     1627.16
# Name: total_bill, dtype: float64

# %%
plt.bar(day.index, day.values)
plt.show()

# %%
gender=tips.groupby("sex")["total_bill"].sum()

# %%
plt.bar(gender.index,gender.values)
# Out:
# <BarContainer object of 2 artists>

# %%
gender = tips.groupby("sex")["total_bill"].sum()
gender.head()
plt.bar(gender.index, gender.values);

# %%
day = tips.groupby("day")["total_bill"].sum().index
tip = tips.groupby("day")["tip"].sum()
total = tips.groupby("day")["total_bill"].sum()
fig, ax = plt.subplots()
ax.bar(day, total, label="total" )
ax.bar(day, tip, label="tip" )
plt.legend()
plt.show()

# %%
day = tips.groupby("day")["total_bill"].sum().index
tip = tips.groupby("day")["tip"].sum()
total = tips.groupby("day")["total_bill"].sum()
x = np.arange(len(day))
width = 0.35
fig, ax = plt.subplots()
ax.bar(x-width/2, total, width, label="total" )
ax.bar(x+width/2, tip,   width, label="tip" )
ax.set_xticks(x)
ax.set_xticklabels(day)
plt.legend()
plt.show()

# %%
plt.hist(tips["tip"], bins= 100)
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.boxplot(tips["tip"], vert=False)
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.boxplot([tips.tip, tips.total_bill], vert=False)
plt.show()

# %%
#plt yerine sns

# %%
sns.scatterplot(x="total_bill",y="tip",data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill",y="tip",data=tips,hue="sex",style="sex")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot("total_bill","tip",data=tips,alpha=0.5);
plt.savefig("focusgroup.jpg")
# Out:
# C:\Users\MTM\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.displot(x="total_bill",data=tips,kde=True)

# %%
sns.histplot(x="total_bill",data=tips,kde=True,bins=50,share=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-5ed37b13437e> in <module>
# ----> 1 sns.histplot(x="total_bill",data=tips,kde=True,bins=50,share=True)
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1421     if p.univariate:
#    1422
# -> 1423         p.plot_univariate_histogram(
#    1424             multiple=multiple,
#    1425             element=element,
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     507                         artist = mpl.patches.Rectangle
#     508                         plot_kws = _normalize_kwargs(plot_kws, artist)
# --> 509                         scout = self.ax.fill_between([], [], color=color, **plot_kws)
#     510                         default_color = tuple(scout.get_facecolor().squeeze())
#     511                 else:
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5299     def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5300                      step=None, **kwargs):
# -> 5301         return self._fill_between_x_or_y(
#    5302             "x", x, y1, y2,
#    5303             where=where, interpolate=interpolate, step=step, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5285             polys.append(pts)
#    5286
# -> 5287         collection = mcoll.PolyCollection(polys, **kwargs)
#    5288
#    5289         # now update the datalim and autoscale
#
# ~\anaconda3\lib\site-packages\matplotlib\collections.py in __init__(self, verts, sizes, closed, **kwargs)
#    1121             Forwarded to `.Collection`.
#    1122         """
# -> 1123         Collection.__init__(self, **kwargs)
#    1124         self.set_sizes(sizes)
#    1125         self.set_verts(verts, closed)
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     211
#     212         self._path_effects = None
# --> 213         self.update(kwargs)
#     214         self._paths = None
#     215
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#     994                     func = getattr(self, f"set_{k}", None)
#     995                     if not callable(func):
# --> 996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
#     998                     ret.append(func(v))
#
# AttributeError: 'PolyCollection' object has no property 'share'
